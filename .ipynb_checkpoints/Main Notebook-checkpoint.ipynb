# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#SAT-&amp;-ACT-Analysis" data-toc-modified-id="SAT-&amp;-ACT-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>SAT &amp; ACT Analysis</a></span><ul class="toc-item"><li><span><a href="#Problem-Statement" data-toc-modified-id="Problem-Statement-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Problem Statement</a></span></li><li><span><a href="#Executive-Summary" data-toc-modified-id="Executive-Summary-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Executive Summary</a></span><ul class="toc-item"><li><span><a href="#Contents:" data-toc-modified-id="Contents:-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Contents:</a></span></li></ul></li><li><span><a href="#2017-Data-Import-and-Cleaning" data-toc-modified-id="2017-Data-Import-and-Cleaning-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>2017 Data Import and Cleaning</a></span></li><li><span><a href="#Additional-Research:" data-toc-modified-id="Additional-Research:-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Additional Research:</a></span><ul class="toc-item"><li><span><a href="#Max-Possible-Score" data-toc-modified-id="Max-Possible-Score-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Max Possible Score</a></span></li><li><span><a href="#From-the-datasets:" data-toc-modified-id="From-the-datasets:-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>From the datasets:</a></span></li><li><span><a href="#Fixing-Errors" data-toc-modified-id="Fixing-Errors-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Fixing Errors</a></span></li><li><span><a href="#Data-Types" data-toc-modified-id="Data-Types-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Data Types</a></span></li><li><span><a href="#Rename-Columns" data-toc-modified-id="Rename-Columns-1.4.5"><span class="toc-item-num">1.4.5&nbsp;&nbsp;</span>Rename Columns</a></span></li><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-1.4.6"><span class="toc-item-num">1.4.6&nbsp;&nbsp;</span>Data Dictionary</a></span></li><li><span><a href="#Drop-Unnecessary-Rows-and-Merge-Dataframes" data-toc-modified-id="Drop-Unnecessary-Rows-and-Merge-Dataframes-1.4.7"><span class="toc-item-num">1.4.7&nbsp;&nbsp;</span>Drop Unnecessary Rows and Merge Dataframes</a></span></li></ul></li><li><span><a href="#2018-Data-Import-and-Cleaning" data-toc-modified-id="2018-Data-Import-and-Cleaning-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>2018 Data Import and Cleaning</a></span></li><li><span><a href="#Combine-the-2017-and-2018-data-into-a-single-dataframe" data-toc-modified-id="Combine-the-2017-and-2018-data-into-a-single-dataframe-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Combine the 2017 and 2018 data into a single dataframe</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis" data-toc-modified-id="Exploratory-Data-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exploratory Data Analysis</a></span><ul class="toc-item"><li><span><a href="#Summary-Statistics" data-toc-modified-id="Summary-Statistics-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Summary Statistics</a></span><ul class="toc-item"><li><span><a href="#Manually-calculate-standard-deviation" data-toc-modified-id="Manually-calculate-standard-deviation-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Manually calculate standard deviation</a></span></li><li><span><a href="#Investigating-trends-in-the-data" data-toc-modified-id="Investigating-trends-in-the-data-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Investigating trends in the data</a></span></li></ul></li><li><span><a href="#Visualize-the-data" data-toc-modified-id="Visualize-the-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Visualize the data</a></span><ul class="toc-item"><li><span><a href="#Use-Seaborn's-heatmap-with-pandas-.corr()-to-visualize-correlations-between-all-numeric-features" data-toc-modified-id="Use-Seaborn's-heatmap-with-pandas-.corr()-to-visualize-correlations-between-all-numeric-features-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Use Seaborn's heatmap with pandas <code>.corr()</code> to visualize correlations between all numeric features</a></span><ul class="toc-item"><li><span><a href="#The-following-pointers-are-being-observed-from-the-above-correlation-heatmap:" data-toc-modified-id="The-following-pointers-are-being-observed-from-the-above-correlation-heatmap:-2.2.1.1"><span class="toc-item-num">2.2.1.1&nbsp;&nbsp;</span>The following pointers are being observed from the above correlation heatmap:</a></span></li></ul></li><li><span><a href="#Plotting-Histograms" data-toc-modified-id="Plotting-Histograms-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Plotting Histograms</a></span><ul class="toc-item"><li><span><a href="#Plot-and-interpret-histograms" data-toc-modified-id="Plot-and-interpret-histograms-2.2.2.1"><span class="toc-item-num">2.2.2.1&nbsp;&nbsp;</span>Plot and interpret histograms</a></span></li></ul></li><li><span><a href="#Plot-and-interpret-scatter-plots" data-toc-modified-id="Plot-and-interpret-scatter-plots-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Plot and interpret scatter plots</a></span></li><li><span><a href="#Boxplot-Analysis" data-toc-modified-id="Boxplot-Analysis-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Boxplot Analysis</a></span></li></ul></li><li><span><a href="#Descriptive-and-Inferential-Statistics" data-toc-modified-id="Descriptive-and-Inferential-Statistics-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Descriptive and Inferential Statistics</a></span><ul class="toc-item"><li><span><a href="#Summarizing-Distributions" data-toc-modified-id="Summarizing-Distributions-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Summarizing Distributions</a></span></li><li><span><a href="#Distributions-in-the-data" data-toc-modified-id="Distributions-in-the-data-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Distributions in the data</a></span></li><li><span><a href="#Estimate-Limits-of-Data" data-toc-modified-id="Estimate-Limits-of-Data-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Estimate Limits of Data</a></span></li></ul></li><li><span><a href="#Outside-Research" data-toc-modified-id="Outside-Research-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Outside Research</a></span></li><li><span><a href="#Conclusions-and-Recommendations" data-toc-modified-id="Conclusions-and-Recommendations-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Conclusions and Recommendations</a></span></li></ul></li></ul></div>

# %% [markdown]
# # SAT & ACT Analysis

# %% [markdown]
# In this project, we will be studying and analyzing the data on SAT & ACT for 2017 and 2018. From the analysis, we will be able to understand what informed decisions can be made for different stakeholders. Stakeholders include the College Board, students, Education Ministry and Universities Administrators.
#
# ## Problem Statement

# %% [markdown]
# SAT and ACT are used for US college application. They are used to measure an individual college readiness and predict future academic success. In this analysis, we will be looking to mainly improve the SAT participation rate by studying the data of SAT test across the 51 states in USA. From there, we will determine how we can improve the participation.

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [2017 Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [2018 Data Import and Cleaning](#2018-Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Descriptive and Inferential Statistics](#Descriptive-and-Inferential-Statistics)
# - [Outside Research](#Outside-Research)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %%
#Importing of Modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

#set max columns display
pd.set_option('max_columns', None)

# %% [markdown]
# ## 2017 Data Import and Cleaning

# %%
#Reading in of SAT & ACT 2017 data
sat_2017 = pd.read_csv('data/sat_2017.csv')
act_2017 = pd.read_csv('data/act_2017.csv')

# %%
#Top 5 rows of ACT dataset
act_2017.head(5)
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
#Top 5 rows of SAT dataset
sat_2017.head(5)
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
act_2017.shape
# Out:
# (52, 7)

# %%
sat_2017.shape
# Out:
# (51, 5)

# %% [markdown]
# There are some differences in the datasets for both tests. There are 7 features in the ACT data which included the State and Participation. The SAT data has 5 features, two of which are State and Participation. The rest of the features are the subject score for each test.
#
# ACT have 52 rows and SAT have 51 rows. In the USA, there are a total of 51 states, which explains the number of rows in SAT. For ACT, there is an additional row which is 'national' in the dataset.

# %%
#Checking for missing data in sat_2017
sat_2017.isnull().sum()
# Out:
# State                                 0
# Participation                         0
# Evidence-Based Reading and Writing    0
# Math                                  0
# Total                                 0
# dtype: int64

# %%
#Checking for missing data in act_2017
act_2017.isnull().sum()
# Out:
# State            0
# Participation    0
# English          0
# Math             0
# Reading          0
# Science          0
# Composite        0
# dtype: int64

# %% [markdown]
# There are no missing data in both datasets.

# %%
act_2017.describe()
# Out:
#          English       Math    Reading    Science
# count  52.000000  52.000000  52.000000  52.000000
# mean   20.919231  21.173077  22.001923  21.040385
# std     2.332132   1.963602   2.048672   3.151113
# min    16.300000  18.000000  18.100000   2.300000
# 25%    19.000000  19.400000  20.475000  19.900000
# 50%    20.550000  20.900000  21.700000  21.150000
# 75%    23.300000  23.100000  24.125000  22.525000
# max    25.500000  25.300000  26.000000  24.900000

# %%
sat_2017.describe()
# Out:
#        Evidence-Based Reading and Writing        Math        Total
# count                           51.000000   51.000000    51.000000
# mean                           569.117647  547.627451  1126.098039
# std                             45.666901   84.909119    92.494812
# min                            482.000000   52.000000   950.000000
# 25%                            533.500000  522.000000  1055.500000
# 50%                            559.000000  548.000000  1107.000000
# 75%                            613.000000  599.000000  1212.000000
# max                            644.000000  651.000000  1295.000000

# %% [markdown]
# ## Additional Research:
#
# As we are looking into the maximum and minimum possible value, we look at some outside sources for reference.
#
# - [SAT](https://blog.collegevine.com/here-are-the-average-sat-scores-by-state/) -
# National Average SAT 2017 Score is 535(ERW),527(Math),1060. Highest is 1295, lowest is 950
#
# - [ACT](https://blog.prepscholar.com/act-scores-by-state-averages-highs-and-lows) -
#  National Average ACT 2019/2020 Score is 20.6. English is 19.9. Math is 20.2. Reading is 21.2. Science is 20.6
#
# ### Max Possible Score
# - ACT - 36
# - SAT - 1600
#
#
# ### From the datasets:
# The following are the min and max score for each subject from our datasets.
#
#
# Act 2017:
# - English Max - 25.5
# - English Min - 16.3
#
# - Math Max - 25.3
# - Math Min - 18.0
#
# - Reading Max - 26.0
# - Reading Min - 18.1
#
# - Science Max - 24.9
# - Science Min - 18.2
#
# - Composite Max - 25.5
# - Composite Min - 23.6
#
# Sat 2017:
# - EBRW  Max - 644
# - EBRW  Min - 482
#
# - Math Max - 651
# - Math Min - 52
#
# - Total Max - 1295
# - Total Min - 950

# %% [markdown]
# ### Fixing Errors
#
# There are some error in the values. It is due to the decimal placing or missing of a digit. We will fix accordingly.

# %%
#Spotted error on ACT 2017 science score
act_2017['Science'][21]
# Out:
# 2.3

# %%
#Fixing the science score result of Maryland
act_2017['Science'][21] = 23.2
# Out:
# <ipython-input-12-56b4b36fdc61>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   act_2017['Science'][21] = 23.2

# %%
#Spotted error on SAT 2017 math score
sat_2017['Math'][20]
# Out:
# 52

# %%
#Fixing the math science result of Maryland
sat_2017['Math'][20] = 524
# Out:
# <ipython-input-14-1bcac978f041>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sat_2017['Math'][20] = 524

# %% [markdown]
# ### Data Types
# Display the data types of each feature.

# %%
#data types for ACT 2017's columns
act_2017.dtypes
# Out:
# State             object
# Participation     object
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite         object
# dtype: object

# %%
#data types for SAT 2017's columns
sat_2017.dtypes
# Out:
# State                                 object
# Participation                         object
# Evidence-Based Reading and Writing     int64
# Math                                   int64
# Total                                  int64
# dtype: object

# %% [markdown]
# Based on the data types, the scoring metrics should be in integer or float for calculation. Therefore, we will be converting the type with the function below.

# %%
def convert_type(column,result_list):
    """Convert the particpation rate data type to float and remove the %"""
    result_list[column] = result_list[column].str.replace('%','')
    result_list[column] = result_list[column].astype(float)

# %%
#Using function to convert data type of 'Participation'
convert_type('Participation',act_2017)

# %%
#Using function to convert data type of 'Participation'
convert_type('Participation',sat_2017)

# %%
##One of the entry in composite has an x. The above code will remove it and convert the whole column into a float
act_2017['Composite'] = act_2017['Composite'].str.replace('x','')
act_2017['Composite'] = act_2017['Composite'].apply(float)

##Change data types to float from integers
sat_2017['Evidence-Based Reading and Writing']= sat_2017['Evidence-Based Reading and Writing'].apply(float)
sat_2017['Math']= sat_2017['Math'].apply(float)
sat_2017['Total']= sat_2017['Total'].apply(float)

# %%
#Checking the data types again
sat_2017.dtypes
# Out:
# State                                  object
# Participation                         float64
# Evidence-Based Reading and Writing    float64
# Math                                  float64
# Total                                 float64
# dtype: object

# %%
#Checking the data types again
act_2017.dtypes
# Out:
# State             object
# Participation    float64
# English          float64
# Math             float64
# Reading          float64
# Science          float64
# Composite        float64
# dtype: object

# %% [markdown]
# ### Rename Columns
#
# Here, we will be renaming the features name for easier reference.

# %%
##Dict for renamed columns
act_2017_columns_dict={'State':'state',
                       'Participation': 'act2017_participation',
                       'English':'act2017_english','Math':'act2017_math',
                       'Reading':'act2017_reading','Science':'act2017_science',
                       'Composite':'act2017_composite'}

# %%
##Renaming of the columns for easier comparison later
act_2017 = act_2017.rename(columns=act_2017_columns_dict)
act_2017.head()
# Out:
#       state  act2017_participation  act2017_english  act2017_math  \
# 0  National                   60.0             20.3          20.7
# 1   Alabama                  100.0             18.9          18.4
# 2    Alaska                   65.0             18.7          19.8
# 3   Arizona                   62.0             18.6          19.8
# 4  Arkansas                  100.0             18.9          19.0
#
#    act2017_reading  act2017_science  act2017_composite
# 0             21.4             21.0               21.0
# 1             19.7             19.4               19.2
# 2             20.4             19.9               19.8
# 3             20.1             19.8               19.7
# 4             19.7             19.5               19.4

# %%
sat_2017_columns_dict={'State':'state','Participation':'sat2017_participation',
                         'Evidence-Based Reading and Writing' : 'sat2017_ebrw',
                         'Math': 'sat2017_math', 'Total':'sat2017_total'}
##Dict for renamed columns

# %%
sat_2017 = sat_2017.rename(columns=sat_2017_columns_dict)
##Renaming of the columns for easier comparison later
sat_2017.head()
# Out:
#         state  sat2017_participation  sat2017_ebrw  sat2017_math  \
# 0     Alabama                    5.0         593.0         572.0
# 1      Alaska                   38.0         547.0         533.0
# 2     Arizona                   30.0         563.0         553.0
# 3    Arkansas                    3.0         614.0         594.0
# 4  California                   53.0         531.0         524.0
#
#    sat2017_total
# 0         1165.0
# 1         1080.0
# 2         1116.0
# 3         1208.0
# 4         1055.0

# %% [markdown]
# ### Data Dictionary
#
# These will be the features and data types we will be using for the data sets up coming.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |column name|int/float/object|ACT/SAT|This is an example|

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |:---:|:---:|:---:|:---:|
# |state|object|ACT/SAT|State
# |act2017_participation|float64|ACT|ACT 2017 Participation Rate
# |act2017_english|float64|ACT|ACT 2017 English Mean Score
# |act2017_math|float64|ACT|ACT 2017 Math Mean Score
# |act2017_reading|float64|ACT|ACT 2017 Reading Mean Score
# |act2017_science|float64|ACT|ACT 2017 Science Mean Score
# |act2017_composite|float64|ACT|ACT 2017 Composite Mean Score
# |sat2017_participation|float64|SAT|SAT 2017 Participation Rate
# |sat2017_ebrw|float64|SAT|SAT 2017 Evidence-Based Reading and Writing Mean Score
# |sat2017_math|float64|SAT|SAT 2017 Math Mean Score
# |sat2017_total|float64|SAT|SAT 2017 Total Mean Score
# |act2018_participation|float64|ACT|ACT 2018 Participation Rate
# |act2018_english|float64|ACT|ACT 2018 English Mean Score
# |act2018_math|float64|ACT|ACT 2018 Math Mean Score
# |act2018_reading|float64|ACT|ACT 2018 Reading Mean Score
# |act2018_science|float64|ACT|ACT 2018 Science Mean Score
# |act2018_composite|float64|ACT|ACT 2018 Composite Mean Score
# |sat2018_participation|float64|SAT|SAT 2018 Participation Rate
# |sat2018_ebrw|float64|SAT|SAT 2018 Evidence-Based Reading and Writing Mean Score
# |sat2018_math|float64|SAT|SAT 2018 Math Mean Score
# |sat2018_total|float64|SAT|SAT 2018 Total Mean Score

# %% [markdown]
# ### Drop Unnecessary Rows and Merge Dataframes
#
# Here we will be merging both datasets together. So we will have to remove the national row. We will be merging based on the feature state.

# %%
#dropping national stats as we cannot compare it to SAT
act_2017 = act_2017.drop([0])
act_2017.head()
# Out:
#         state  act2017_participation  act2017_english  act2017_math  \
# 1     Alabama                  100.0             18.9          18.4
# 2      Alaska                   65.0             18.7          19.8
# 3     Arizona                   62.0             18.6          19.8
# 4    Arkansas                  100.0             18.9          19.0
# 5  California                   31.0             22.5          22.7
#
#    act2017_reading  act2017_science  act2017_composite
# 1             19.7             19.4               19.2
# 2             20.4             19.9               19.8
# 3             20.1             19.8               19.7
# 4             19.7             19.5               19.4
# 5             23.1             22.2               22.8

# %%
#merge both df based on state as key
df_2017 = pd.merge(act_2017,sat_2017,on='state')

# %%
#Save combined dataset
df_2017.to_csv('data/combined_2017.csv',index=False)

# %% [markdown]
# ## 2018 Data Import and Cleaning
#
# In this section, we will be importing 2018 datasets and clean it the same way as 2017 dataset. After cleaning each individual dataset, we will be merging them into one.

# %%
#Importing of datasets
sat_2018 = pd.read_csv('data/sat_2018.csv')
act_2018 = pd.read_csv('data/act_2018_updated.csv')

# %%
#Change the percentage of students tested to float
act_2018['Percentage of Students Tested'] = act_2018['Percentage of Students Tested'].astype(float)

# %%
#dict of columns name for act2018
act_2018_columns_dict={'State':'state','Percentage of Students Tested':'act2018_participation',
                       'Average English Score':'act2018_english','Average Math Score':'act2018_math', 
                       'Average Reading Score':'act2018_reading','Average Science Score':'act2018_science',
                        'Average Composite Score':'act2018_composite'}

# %%
#renaming the headers so it will be easier to compare data 
act_2018 = act_2018.rename(columns=act_2018_columns_dict)

# %%
act_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  51 non-null     object
#  1   act2018_participation  51 non-null     float64
#  2   act2018_composite      51 non-null     float64
#  3   act2018_english        51 non-null     float64
#  4   act2018_math           51 non-null     float64
#  5   act2018_reading        51 non-null     float64
#  6   act2018_science        51 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 2.9+ KB

# %%
##Using the function created earlier, change the data type of Participation to float
convert_type('Participation',sat_2018)

# %%
#Converting data types for the above variables to float
sat_2018['Evidence-Based Reading and Writing'] = sat_2018['Evidence-Based Reading and Writing'].astype(float)
sat_2018['Math'] = sat_2018['Math'].astype(float)
sat_2018['Total'] = sat_2018['Total'].astype(float)

# %%
#dict of columns name for sat2018
sat_2018_columns_dict={'State':'state','Participation':'sat2018_participation',
                       'Evidence-Based Reading and Writing':'sat2018_ebrw',
                        'Math':'sat2018_math', 'Total':'sat2018_total'}

#renaming the headers so it will be easier to compare data to SAT 2017
sat_2018 = sat_2018.rename(columns=sat_2018_columns_dict)

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  51 non-null     object
#  1   sat2018_participation  51 non-null     float64
#  2   sat2018_ebrw           51 non-null     float64
#  3   sat2018_math           51 non-null     float64
#  4   sat2018_total          51 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
#Merging act_2018 and sat_2018 into one
df_2018 = pd.merge(act_2018,sat_2018,on='state')

#Making sure the rows and columns are the same as df_2017
df_2018.shape
# Out:
# (51, 11)

# %%
#saving a version of combined 2018 df
df_2018.to_csv('data/combined_2018.csv',index=False)

# %% [markdown]
# ## Combine the 2017 and 2018 data into a single dataframe
#
# This section we will be combining both datasets into one.

# %%
#combined of both 2017 and 2018 datasets
combined_df = pd.merge(df_2017,df_2018,on='state')

# %%
combined_df.to_csv('data/final.csv',index=False)

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 50
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   state                  51 non-null     object
#  1   act2017_participation  51 non-null     float64
#  2   act2017_english        51 non-null     float64
#  3   act2017_math           51 non-null     float64
#  4   act2017_reading        51 non-null     float64
#  5   act2017_science        51 non-null     float64
#  6   act2017_composite      51 non-null     float64
#  7   sat2017_participation  51 non-null     float64
#  8   sat2017_ebrw           51 non-null     float64
#  9   sat2017_math           51 non-null     float64
#  10  sat2017_total          51 non-null     float64
#  11  act2018_participation  51 non-null     float64
#  12  act2018_composite      51 non-null     float64
#  13  act2018_english        51 non-null     float64
# ...

# %%
#Final combined dataset
combined_df.head()
# Out:
#         state  act2017_participation  act2017_english  act2017_math  \
# 0     Alabama                  100.0             18.9          18.4
# 1      Alaska                   65.0             18.7          19.8
# 2     Arizona                   62.0             18.6          19.8
# 3    Arkansas                  100.0             18.9          19.0
# 4  California                   31.0             22.5          22.7
#
#    act2017_reading  act2017_science  act2017_composite  sat2017_participation  \
# 0             19.7             19.4               19.2                    5.0
# 1             20.4             19.9               19.8                   38.0
# 2             20.1             19.8               19.7                   30.0
# 3             19.7             19.5               19.4                    3.0
# 4             23.1             22.2               22.8                   53.0
#
#    sat2017_ebrw  sat2017_math  sat2017_total  act2018_participation  \
# ...

# %% [markdown]
# # Exploratory Data Analysis
#
# ## Summary Statistics
# Transpose the output of pandas `describe` method to create a quick overview of each numeric feature.

# %%
#describing a transposed dataframe
round(combined_df.describe().transpose(),2)
# Out:
#                        count     mean    std    min      25%     50%      75%  \
# act2017_participation   51.0    65.25  32.14    8.0    31.00    69.0   100.00
# act2017_english         51.0    20.93   2.35   16.3    19.00    20.7    23.30
# act2017_math            51.0    21.18   1.98   18.0    19.40    20.9    23.10
# act2017_reading         51.0    22.01   2.07   18.1    20.45    21.8    24.15
# act2017_science         51.0    21.45   1.74   18.2    19.95    21.3    23.20
# act2017_composite       51.0    21.52   2.02   17.8    19.80    21.4    23.60
# sat2017_participation   51.0    39.80  35.28    2.0     4.00    38.0    66.00
# sat2017_ebrw            51.0   569.12  45.67  482.0   533.50   559.0   613.00
# sat2017_math            51.0   556.88  47.12  468.0   523.50   548.0   599.00
# sat2017_total           51.0  1126.10  92.49  950.0  1055.50  1107.0  1212.00
# act2018_participation   51.0    61.65  34.08    7.0    28.50    66.0   100.00
# ...

# %% [markdown]
# ### Manually calculate standard deviation
#
# We will attempt to calculate the standard deviation by creating a function.
#
#
# $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$

# %%
def cal_std(data_points):
    """Getting data_points as list and apply std deviation formula"""
    total_sq_dev = [] #Create a list to put in all the data_points after minus off the mean
    n = len(data_points) #Counting the number of data points
    data_points = list(data_points) #Listing the data points
    data_mean = sum(data_points)/n ##Getting the mean
    for i in data_points:
        sq_dev = (i - data_mean)**2
        total_sq_dev.append(sq_dev) 
    vari = sum(total_sq_dev)/n ##Getting the variance
    std = vari**0.5 #Getting the standard deviation
    return std

# %%
#A function test on a column
cal_std(combined_df['act2017_participation'])
# Out:
# 31.824175751231806

# %% [markdown]
# - Use a **dictionary comprehension** to apply your standard deviation function to each numeric column in the dataframe.  **No loops**
# - Assign the output to variable `sd` as a dictionary where:
#     - Each column name is now a key
#     - That standard deviation of the column is the value
#
# *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`

# %%
#Turning columns into keys
sd_keys = combined_df.columns
sd_keys = list(sd_keys)

# %%
#Using dictionary comprehension to create dictionary for std
sd = {sd_keys[i]:round(cal_std(combined_df[sd_keys[i]]),2) for i in range(1,len(sd_keys))}
sd

# %% [markdown]
# Using the manually calculated standard deviation, we compare them to the standard deviation that is calculated by np.

# %% [markdown]
# The calculated std using the functions and the std from the pandas have a difference of 0.3. Please refer to the .describe() below.
#
# The calculated std and the numpy's std is the same. Please refer to the np.std below.

# %%
 ##pandas'std
combined_df['act2017_participation'].describe()
# Out:
# count     51.000000
# mean      65.254902
# std       32.140842
# min        8.000000
# 25%       31.000000
# 50%       69.000000
# 75%      100.000000
# max      100.000000
# Name: act2017_participation, dtype: float64

# %%
##numpy's std
np.std(combined_df['act2017_participation'])
# Out:
# 31.824175751231806

# %% [markdown]
# ### Investigating trends in the data
#
# We will be studying the following trends from our datasets:
#
# - Which states have the highest and lowest participation rates for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Which states have the highest and lowest mean total/composite scores for the:
#     - 2017 SAT?
#     - 2018 SAT?
#     - 2017 ACT?
#     - 2018 ACT?
# - Do any states with 100% participation on a given test have a rate change year-to-year?
# - Do any states show have >50% participation on *both* tests either year?

# %%
#Lowest participation state for SAT2017 
combined_df[['state','sat2017_participation']].sort_values(by = 'sat2017_participation').head()
# Out:
#            state  sat2017_participation
# 34  North Dakota                    2.0
# 24   Mississippi                    2.0
# 15          Iowa                    2.0
# 25      Missouri                    3.0
# 44          Utah                    3.0

# %% [markdown]
# Lowest Participation States for SAT 2017 are North Dakota, Mississippi and Iowa.

# %%
#Highest Participation for SAT2017
combined_df[['state','sat2017_participation']].sort_values(by = 'sat2017_participation').tail()
# Out:
#                    state  sat2017_participation
# 29         New Hampshire                   96.0
# 22              Michigan                  100.0
# 8   District of Columbia                  100.0
# 7               Delaware                  100.0
# 6            Connecticut                  100.0

# %% [markdown]
# Highest Participation States for SAT 2017 are Michigan, District of Columbia, Delaware and Connecticut.

# %%
#Lowest Participaiton for SAT2018
combined_df[['state','sat2018_participation']].sort_values(by = 'sat2018_participation').head()
# Out:
#            state  sat2018_participation
# 34  North Dakota                    2.0
# 50       Wyoming                    3.0
# 41  South Dakota                    3.0
# 27      Nebraska                    3.0
# 49     Wisconsin                    3.0

# %% [markdown]
# Lowest Particiation State for SAT 2018 is North Dakota which had the same participation rate as the previous year.

# %%
#Highest Participaiton for SAT2018
combined_df[['state','sat2018_participation']].sort_values(by = 'sat2018_participation').tail(10)
# Out:
#                    state  sat2018_participation
# 8   District of Columbia                   92.0
# 29         New Hampshire                   96.0
# 39          Rhode Island                   97.0
# 19                 Maine                   99.0
# 13              Illinois                   99.0
# 5               Colorado                  100.0
# 6            Connecticut                  100.0
# 7               Delaware                  100.0
# 22              Michigan                  100.0
# 12                 Idaho                  100.0

# %% [markdown]
# Highest Participation States for SAT 2018 are Colorado, Connecticut, Delaware, Michigan and Idaho.

# %%
#Lowest participation state for ACT2017 is Maine
combined_df[['state','act2017_participation']].sort_values(by = 'act2017_participation').head()
# Out:
#             state  act2017_participation
# 19          Maine                    8.0
# 29  New Hampshire                   18.0
# 7        Delaware                   18.0
# 39   Rhode Island                   21.0
# 38   Pennsylvania                   23.0

# %% [markdown]
# Lowest Participation State for ACT 2017 is Maine

# %%
#Highest participaiton states for ACT2017
combined_df[['state','act2017_participation']].sort_values(by = 'act2017_participation').tail(20)
# Out:
#              state  act2017_participation
# 11          Hawaii                   90.0
# 13        Illinois                   93.0
# 34    North Dakota                   98.0
# 40  South Carolina                  100.0
# 44            Utah                  100.0
# 42       Tennessee                  100.0
# 0          Alabama                  100.0
# 25        Missouri                  100.0
# 33  North Carolina                  100.0
# 28          Nevada                  100.0
# 26         Montana                  100.0
# 49       Wisconsin                  100.0
# 24     Mississippi                  100.0
# 23       Minnesota                  100.0
# 18       Louisiana                  100.0
# 17        Kentucky                  100.0
# 5         Colorado                  100.0
# 3         Arkansas                  100.0
# 36        Oklahoma                  100.0
# 50         Wyoming                  100.0

# %% [markdown]
# Highest Participation States for ACT 2017 are Kentucky, Colorado, Arkansas, Oklahoma, Wyoming, Louisiana, Minnesota, Wisconsin, Montana, Nevada, North Carolina, Missouri, Alabama, Tennessee, Utah and South Carolina.

# %%
#Lowest ACT Participation State
combined_df[['state','act2018_participation']].sort_values(by = 'act2018_participation').head()
# Out:
#             state  act2018_participation
# 19          Maine                    7.0
# 39   Rhode Island                   15.0
# 29  New Hampshire                   16.0
# 7        Delaware                   17.0
# 38   Pennsylvania                   20.0

# %% [markdown]
# Lowest Participation State for ACT 2018 is Maine. It is the same for ACT 2017

# %%
#Highest ACT Participation State
combined_df[['state','act2018_participation']].sort_values(by = 'act2018_participation').tail(20)
# Out:
#              state  act2018_participation
# 11          Hawaii                   89.0
# 34    North Dakota                   98.0
# 23       Minnesota                   99.0
# 44            Utah                  100.0
# 42       Tennessee                  100.0
# 40  South Carolina                  100.0
# 0          Alabama                  100.0
# 25        Missouri                  100.0
# 35            Ohio                  100.0
# 33  North Carolina                  100.0
# 28          Nevada                  100.0
# 27        Nebraska                  100.0
# 26         Montana                  100.0
# 49       Wisconsin                  100.0
# 24     Mississippi                  100.0
# 18       Louisiana                  100.0
# 17        Kentucky                  100.0
# 3         Arkansas                  100.0
# 36        Oklahoma                  100.0
# 50         Wyoming                  100.0

# %% [markdown]
# There are many states with 100% participation for ACT 2018. They are Kentucky, Arkansas, Oklahoma, Wyoming, Louisiana, Mississippi, Wisconsin, Montana, Nebraska, Nevada, North Carolina, Missouri, Alabama, Ohio, Tennessee, Utah and South Carolina.

# %%
#Finding lowest SAT 2017 mean total
combined_df[['state','sat2017_total']].sort_values(by = 'sat2017_total').head()
# Out:
#                    state  sat2017_total
# 8   District of Columbia          950.0
# 7               Delaware          996.0
# 12                 Idaho         1005.0
# 22              Michigan         1005.0
# 19                 Maine         1012.0

# %% [markdown]
# State with lowest SAT 2017 mean total score is District of Columbia. 2nd lowest is Delaware with a difference of 46 points.

# %%
#Finding highest SAT 2017 mean total
combined_df[['state','sat2017_total']].sort_values(by = 'sat2017_total').tail()
# Out:
#         state  sat2017_total
# 16     Kansas         1260.0
# 25   Missouri         1271.0
# 15       Iowa         1275.0
# 49  Wisconsin         1291.0
# 23  Minnesota         1295.0

# %% [markdown]
# State with highest SAT 2017 mean total score is Minnesota. The runner up is Wisconsin with a difference of 4 points.

# %%
#Finding lowest SAT mean 2018 total
combined_df[['state','sat2018_total']].sort_values(by = 'sat2018_total').head()
# Out:
#                    state  sat2018_total
# 8   District of Columbia          977.0
# 7               Delaware          998.0
# 48         West Virginia          999.0
# 12                 Idaho         1001.0
# 44                  Utah         1010.0

# %% [markdown]
# State with lowest SAT 2018 mean total score is District of Columbia. It also had the lowest mean score in the previous year. 2nd lowest is Delaware, which is the same as the previous year. Nevertheless, both states have an improvement in score. 27 points for District of Columbia and 2 points for Delaware.

# %%
#Finding highest SAT 2018 mean total
combined_df[['state','sat2018_total']].sort_values(by = 'sat2018_total').tail()
# Out:
#            state  sat2018_total
# 16        Kansas         1265.0
# 15          Iowa         1265.0
# 34  North Dakota         1283.0
# 49     Wisconsin         1294.0
# 23     Minnesota         1298.0

# %% [markdown]
# State with highest SAT 2018 mean total score is Minnesota. It is the same in 2017 and it has an improvement of 3 points. The runner up is Wisconsin, which is the same as previous year. It also has an improvement of 3 points.

# %%
#Finding lowest ACT 2017 composite total
combined_df[['state','act2017_composite']].sort_values(by = 'act2017_composite').head()
# Out:
#              state  act2017_composite
# 28          Nevada               17.8
# 24     Mississippi               18.6
# 40  South Carolina               18.7
# 11          Hawaii               19.0
# 33  North Carolina               19.1

# %% [markdown]
# State with the lowest ACT 2017 mean composite score is Nevada. The 2nd lowest is Mississippi with a difference of 0.8 points.

# %%
#Finding highest ACT 2017 composite total
combined_df[['state','act2017_composite']].sort_values(by = 'act2017_composite').tail()
# Out:
#                    state  act2017_composite
# 8   District of Columbia               24.2
# 19                 Maine               24.3
# 6            Connecticut               25.2
# 21         Massachusetts               25.4
# 29         New Hampshire               25.5

# %% [markdown]
# State with the highest ACT 2017 mean composite score is New Hampshire. The runner up is Masssachusetts, with a difference of 0.1 points.

# %%
#Finding lowest ACT 2018 composite total
combined_df[['state','act2018_composite']].sort_values(by = 'act2018_composite').head()
# Out:
#              state  act2018_composite
# 28          Nevada               17.7
# 40  South Carolina               18.3
# 24     Mississippi               18.6
# 11          Hawaii               18.9
# 0          Alabama               19.1

# %% [markdown]
# State with the lowest ACT 2018 mean composite score is Nevada. It is the same in 2017 and it decreases by 0.1. 2nd lowest is South Carolina with a differnce of 0.6 points.

# %%
#Finding highest ACT 2018 composite total
combined_df[['state','act2018_composite']].sort_values(by = 'act2018_composite').tail()
# Out:
#             state  act2018_composite
# 22       Michigan               24.4
# 32       New York               24.5
# 29  New Hampshire               25.1
# 21  Massachusetts               25.5
# 6     Connecticut               25.6

# %% [markdown]
# State with the highest ACT 2018 composite mean score is Connecticut. The state saw an increase of 0.4 in its composite mean score from 2017. The runner up is Masssachusetts, which is the same as the previous year. It has an improvement of 0.1 point.

# %%
#Comparing on ACT 100% participation rate change
combined_df.loc[combined_df['act2017_participation']==100,['state','act2017_participation','act2018_participation']]
# Out:
#              state  act2017_participation  act2018_participation
# 0          Alabama                  100.0                  100.0
# 3         Arkansas                  100.0                  100.0
# 5         Colorado                  100.0                   30.0
# 17        Kentucky                  100.0                  100.0
# 18       Louisiana                  100.0                  100.0
# 23       Minnesota                  100.0                   99.0
# 24     Mississippi                  100.0                  100.0
# 25        Missouri                  100.0                  100.0
# 26         Montana                  100.0                  100.0
# 28          Nevada                  100.0                  100.0
# 33  North Carolina                  100.0                  100.0
# 36        Oklahoma                  100.0                  100.0
# 40  South Carolina                  100.0                  100.0
# ...

# %% [markdown]
# 15 out of 17 states have 100% participation in both year 2017 and 2018. In 2018, Colorado saw a 70% drop in ACT participation and Minnesota saw a 1% drop.

# %%
#Comparing on SAT 100% participation rate change
combined_df.loc[combined_df['sat2017_participation']==100,['state','sat2017_participation','sat2018_participation']]
# Out:
#                    state  sat2017_participation  sat2018_participation
# 6            Connecticut                  100.0                  100.0
# 7               Delaware                  100.0                  100.0
# 8   District of Columbia                  100.0                   92.0
# 22              Michigan                  100.0                  100.0

# %% [markdown]
# 3 out of 4 states have 100% participation in both years. District of Columbia saw a drop of 7% in SAT participation.

# %%
#States with ACT and SAT participation more than 50% in 2017
combined_df.loc[((combined_df['act2017_participation'] >= 50)&(combined_df['sat2017_participation'] >= 50)),['state','act2017_participation','sat2017_participation']]
# Out:
#              state  act2017_participation  sat2017_participation
# 9          Florida                   73.0                   83.0
# 10         Georgia                   55.0                   61.0
# 11          Hawaii                   90.0                   55.0
# 40  South Carolina                  100.0                   50.0

# %% [markdown]
# In 2017, Florida, Georgia, Hawaii and South Carolina are the only states with ACT and SAT partcipation rates higher than 50%.

# %%
#States with ACT and SAT participation more than 50% in 2018
combined_df.loc[((combined_df['act2018_participation'] >= 50)&(combined_df['sat2018_participation'] >= 50)),['state','act2018_participation','sat2018_participation']]
# Out:
#              state  act2018_participation  sat2018_participation
# 9          Florida                   66.0                   56.0
# 10         Georgia                   53.0                   70.0
# 11          Hawaii                   89.0                   56.0
# 33  North Carolina                  100.0                   52.0
# 40  South Carolina                  100.0                   55.0

# %% [markdown]
# In 2018, Florida, Georgia, Hawaii, North Carolina and South Carolina are the only states with ACT and SAT partcipation rates higher than 50%.

# %%
#Comparing datas from act2017 full participation to sat2017 participation
combined_df.loc[combined_df['act2017_participation'] == 100,['state','act2017_participation','sat2017_participation']]
# Out:
#              state  act2017_participation  sat2017_participation
# 0          Alabama                  100.0                    5.0
# 3         Arkansas                  100.0                    3.0
# 5         Colorado                  100.0                   11.0
# 17        Kentucky                  100.0                    4.0
# 18       Louisiana                  100.0                    4.0
# 23       Minnesota                  100.0                    3.0
# 24     Mississippi                  100.0                    2.0
# 25        Missouri                  100.0                    3.0
# 26         Montana                  100.0                   10.0
# 28          Nevada                  100.0                   26.0
# 33  North Carolina                  100.0                   49.0
# 36        Oklahoma                  100.0                    7.0
# 40  South Carolina                  100.0                   50.0
# ...

# %% [markdown]
# 15 States with full ACT 2017 participation have less than 30% participation in SAT 2017,except for North and South Carolina.

# %%
#Comparing datas from sat2017 full participation to act2017 participation
combined_df.loc[combined_df['sat2017_participation'] == 100,['state','act2017_participation','sat2017_participation']]
# Out:
#                    state  act2017_participation  sat2017_participation
# 6            Connecticut                   31.0                  100.0
# 7               Delaware                   18.0                  100.0
# 8   District of Columbia                   32.0                  100.0
# 22              Michigan                   29.0                  100.0

# %% [markdown]
# 4 States with full SAT 2017 participation have less than 35% participation in SAT 2017. However, all of them are still above 15%.

# %%
#Comparing datas from act2018 full participation to sat2018 participation
combined_df.loc[combined_df['act2018_participation'] == 100,['state','act2018_participation','sat2018_participation']]
# Out:
#              state  act2018_participation  sat2018_participation
# 0          Alabama                  100.0                    6.0
# 3         Arkansas                  100.0                    5.0
# 17        Kentucky                  100.0                    4.0
# 18       Louisiana                  100.0                    4.0
# 24     Mississippi                  100.0                    3.0
# 25        Missouri                  100.0                    4.0
# 26         Montana                  100.0                   10.0
# 27        Nebraska                  100.0                    3.0
# 28          Nevada                  100.0                   23.0
# 33  North Carolina                  100.0                   52.0
# 35            Ohio                  100.0                   18.0
# 36        Oklahoma                  100.0                    8.0
# 40  South Carolina                  100.0                   55.0
# ...

# %% [markdown]
# In the 17 states with full participation in ACT 2018, only North and South Carolina have more than 50% participation in SAT. Out of the remaining 17, 12 has participation less than 10%.

# %%
#Comparing datas from sat2018 full participation to act2018 participation
combined_df.loc[combined_df['sat2018_participation'] == 100,['state','act2018_participation','sat2018_participation']]
# Out:
#           state  act2018_participation  sat2018_participation
# 5      Colorado                   30.0                  100.0
# 6   Connecticut                   26.0                  100.0
# 7      Delaware                   17.0                  100.0
# 12        Idaho                   36.0                  100.0
# 22     Michigan                   22.0                  100.0

# %% [markdown]
# In 2018, there are 5 states with full SAT participation. All of their ACT participation that year range between 17% to 36%.

# %%
combined_df.loc[combined_df['state'] == 'District of Columbia',['state','sat2017_participation','sat2017_total','sat2018_participation','sat2018_total']] #Interesting State
# Out:
#                   state  sat2017_participation  sat2017_total  \
# 8  District of Columbia                  100.0          950.0
#
#    sat2018_participation  sat2018_total
# 8                   92.0          977.0

# %% [markdown]
# District of Columbia had full participation in 2017 and a participation of above 90% in 2018. However, in both years, it has the lowest total mean score across the states.

# %%
combined_df.loc[combined_df['state']=='Nevada',['state','act2017_participation','act2017_composite','act2018_participation','act2018_composite']] #Interesting State
# Out:
#      state  act2017_participation  act2017_composite  act2018_participation  \
# 28  Nevada                  100.0               17.8                  100.0
#
#     act2018_composite
# 28               17.7

# %% [markdown]
# Nevada had full participation for both years, however, they have the lowest composite mean score across the states.

# %%
combined_df.loc[combined_df['state']=='Minnesota',['state','act2017_participation','act2017_composite','act2018_participation','act2018_composite','sat2017_participation','sat2017_total','sat2018_participation','sat2018_total']] #Interesting State
# Out:
#         state  act2017_participation  act2017_composite  \
# 23  Minnesota                  100.0               21.5
#
#     act2018_participation  act2018_composite  sat2017_participation  \
# 23                   99.0               21.3                    3.0
#
#     sat2017_total  sat2018_participation  sat2018_total
# 23         1295.0                    4.0         1298.0

# %% [markdown]
# Minnesota is quite interesting.
# They have the highest total score for SAT 2017 and 2018 but one of the low participating states in both years.
# They also have a full participation in ACT 2017 and a 99% participation in ACT 2018.
# The 2017 ACT Composite score is 21.5, states' highest is 25.5. Median is 21.4
# The 2018 ACT Composite score is 21.3, states' highest is 25.6. Median is 21.3
# Minnesota students seemed to be quite good at studying

# %% [markdown]
# ## Visualize the data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers.
#
# Some recommendations on plotting:
# - Plots have titles
# - Plots have axis labels
# - Plots have appropriate tick labels
# - All text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Plots are interpreted to aid understanding
#
# There is such a thing as too many plots, and there are a *lot* of bad plots. You might make some! (But hopefully not with the guided prompts below).

# %% [markdown]
# ### Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features
#
# Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#
# *example*:
# ```python
# sns.heatmap(df.corr())
# ```
#
# Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).

# %%
#display the correlation table
combined_df.corr()
# Out:
#                        act2017_participation  act2017_english  act2017_math  \
# act2017_participation               1.000000        -0.843501     -0.861114
# act2017_english                    -0.843501         1.000000      0.967803
# act2017_math                       -0.861114         0.967803      1.000000
# act2017_reading                    -0.866620         0.985999      0.979630
# act2017_science                    -0.836595         0.980042      0.986929
# act2017_composite                  -0.858134         0.990856      0.990451
# sat2017_participation              -0.841234         0.686889      0.710697
# sat2017_ebrw                        0.716153        -0.461345     -0.486126
# sat2017_math                        0.682572        -0.420673     -0.420456
# sat2017_total                       0.701477        -0.441947     -0.454116
# act2018_participation               0.919171        -0.796637     -0.813410
# ...

# %%
plt.figure(figsize = (15,10)) #adjusting size for heatmap
ax = plt.axes()
ax.set_title('Correlation of SAT and ACT mean data for 2017 & 2018', fontsize = 20) #adding title into heatmap
corr = combined_df.corr()
sns.heatmap(corr, annot = True,ax=ax,cmap = 'RdYlBu',vmin = -1, vmax = 1)#plotting the heatmap with the range of 1 to -1 for correlation
# Out:
# <AxesSubplot:title={'center':'Correlation of SAT and ACT mean data for 2017 & 2018'}>

# %% [markdown]
# #### The following pointers are being observed from the above correlation heatmap:
#
#
# 1) There is a very high negative correlation between the participation for SAT and ACT in both years. The correlation in 2017 is -0.84 and the correlation in 2018 is -0.87. This means that there is a very low percentage of candidates taking both tests in a year.
#
# 2) Despite both tests have math as a sub-test, it seems that the standards are different. There is a -0.43 correlation in 2017 and -0.38 correlation in 2018.
#
# 3) There is always a negative correlation between the participation and total/composite mean scores for both tests. The more people take the tests, the lower the average will get.

# %% [markdown]
# ### Plotting Histograms
#
# We have data for two tests for two years and here we will be plotting histograms for visualization.

# %%
def subplot_histograms(dataframe, list_of_columns, list_of_titles, list_of_xlabels, list_of_ylabels):
    nrows = int(np.ceil(len(list_of_columns)/2))
    fig, ax = plt.subplots(nrows=nrows, ncols=2,figsize =(12,6*nrows)) # subplotting
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(list_of_columns): 
        ax[i].hist(dataframe[column],bins=8)
        ax[i].axvline(dataframe[column].median(),color ='r', linestyle='-',linewidth=2)
        ax[i].axvline(dataframe[column].mean(),color ='y', linestyle='dashdot',linewidth=2)
    #enumerate through the list of titles and apply to each indvidual subplots
        for i,t in enumerate(list_of_titles):
            ax[i].set_title(t)
    #enumerate through the list of xlabels and apply to each individual subplots' x axis
            for i,x in enumerate(list_of_xlabels):
                ax[i].set_xlabel(x)
    #enumerate through the list of ylabels and apply to each individual subplots' y axis            
                for i,y in enumerate(list_of_ylabels):
                    ax[i].set_ylabel(y)
                    ax[i].grid(b=True)
                    ax[i].legend({'Median':dataframe[column].median(),'Mean':dataframe[column].mean()})

# %% [markdown]
# #### Plot and interpret histograms
# For each of the following:
# - Participation rates for SAT & ACT
# - Math scores for SAT & ACT
# - Reading/verbal scores for SAT & ACT

# %%
subplot_histograms(combined_df,['act2017_participation','sat2017_participation','act2018_participation','sat2018_participation'],['ACT2017_Participation','SAT2017_Participation','ACT2018_Participation','SAT2018_Participation'],['Participation','Participation','Participation','Participation'],['Number of States','Number of States','Number of States','Number of States'])
#Participation rates for SAT & ACT 2017 and 2018

# %%
combined_df[['act2017_participation','sat2017_participation','act2018_participation','sat2018_participation']].describe()
# Out:
#        act2017_participation  sat2017_participation  act2018_participation  \
# count              51.000000              51.000000              51.000000
# mean               65.254902              39.803922              61.647059
# std                32.140842              35.276632              34.080976
# min                 8.000000               2.000000               7.000000
# 25%                31.000000               4.000000              28.500000
# 50%                69.000000              38.000000              66.000000
# 75%               100.000000              66.000000             100.000000
# max               100.000000             100.000000             100.000000
#
#        sat2018_participation
# count              51.000000
# mean               45.745098
# std                37.314256
# min                 2.000000
# 25%                 4.500000
# 50%                52.000000
# 75%                77.500000
# max               100.000000

# %% [markdown]
# The above sub-histogram for the participation for each test for both 2017 and 2018. The y-axis reflected the number of states according to the level of participation in the x-axis.
#
# ###### ACT Participation Rate:
# Based on the histograms and .describe:
# The 2017 ACT test histogram has a median of 69 and the mean,65 is smaller the median.
# The 2018 ACT test histogram has a median of 66 and the mean is 61.6. Both of them have an undefined bimodal shape.
# In 2017, it has more than 17.5 states which have a participation of about 92 to 100. It has more than 12 states which have participation between 20 - 40. In 2018, there are more states having participation of less than 20.
#
# ###### SAT Participation Rate:
# Based on the histograms and .describe:
# The 2017 SAT test histogram has a median of close to 38 and the mean is 39.8.
# The 2018 SAT test histogram has a median of close to 52 and the mean,45.7 is smaller than the median. The 2018's median and mean is larger than the 2017's. Both of them are undefined bimodal shape. In 2017, there is more than 20 states which have a participation of less than 20. In 2018, there is a increase in the states with participation of 80 and above.
#
# Comparing both ACT and SAT tests participation, it seems that ACT has more than 17 states which has participation of 80 and above, whereas SAT has more than 17 states that has participation lower than 20.

# %%
subplot_histograms(combined_df,['act2017_math','sat2017_math','act2018_math','sat2018_math'],['ACT 2017','SAT 2017','ACT 2018','SAT 2018'],['Math','Math','Math','Math'],['Number of States','Number of States','Number of States','Number of States'])
#Math mean score for SAT and ACT

# %%
combined_df[['act2017_math','sat2017_math','act2018_math','sat2018_math']].describe()
# Out:
#        act2017_math  sat2017_math  act2018_math  sat2018_math
# count     51.000000     51.000000     51.000000     51.000000
# mean      21.182353    556.882353     21.125490    556.235294
# std        1.981989     47.121395      2.035765     47.772623
# min       18.000000    468.000000     17.800000    480.000000
# 25%       19.400000    523.500000     19.400000    522.500000
# 50%       20.900000    548.000000     20.700000    544.000000
# 75%       23.100000    599.000000     23.150000    593.500000
# max       25.300000    651.000000     25.200000    655.000000

# %% [markdown]
# The above histograms are comparing the Math Mean Score for ACT and SAT in 2017 and 2018. The x axis reflects the Math Mean Score. The y axis reflects the number of state.
#
# ###### ACT Math Mean Score
# Based on the histograms and .describe:
# For the ACT tests,the histograms'shape are undefined bimodal. ACT 2017 Math Mean Score's median is 20.9 and is very close to the mean which is 21.18. ACT 2018's median is 20.7 and is larger than the mean, 21.12.
#
# ###### SAT Math Mean Score
# Based on the histograms and .describe:
# For the SAT tests, the histograms are skewed to the right. SAT 2017 Math Mean Score's median score is 548, whereas its mean is 556.88. SAT 2018 Math Mean Score's median is above 544, and the mean is 556.24 compared to the previous year.

# %%
subplot_histograms(combined_df,['act2017_reading','sat2017_ebrw','act2018_reading','sat2018_ebrw'],['ACT2017 Reading','SAT2017 EBRW','ACT2018 Reading','SAT2018 EBRW'],['Reading','EBRW','Reading','EBRW'],['Number of States','Number of States','Number of States','Number of States'])
##Plotting histograms for reading and ebrw

# %%
combined_df[['act2017_reading','sat2017_ebrw','act2018_reading','sat2018_ebrw']].describe()
# Out:
#        act2017_reading  sat2017_ebrw  act2018_reading  sat2018_ebrw
# count        51.000000     51.000000        51.000000     51.000000
# mean         22.013725    569.117647        22.015686    563.686275
# std           2.067271     45.666901         2.167245     47.502627
# min          18.100000    482.000000        18.000000    480.000000
# 25%          20.450000    533.500000        20.450000    534.500000
# 50%          21.800000    559.000000        21.600000    552.000000
# 75%          24.150000    613.000000        24.100000    610.500000
# max          26.000000    644.000000        26.100000    643.000000

# %% [markdown]
# The above histograms are comparing the Reading Score for ACT and the Evidence-Based,Reading and Writing score for SAT in 2017 and 2018. The x axis reflects the Mean Score. The y axis reflects the number of state.
#
# ###### ACT Reading Mean Score:
# Based on the histograms and .describe: For the ACT tests,the histograms'shape are undefined bimodal. ACT 2017 Mean Score's median is 21.8 and the mean is 22.01. ACT 2018's median is 21.6 and is smaller than the mean, 22.01. The histograms are undefined bimodal.
#
# ###### SAT Evidence-Based,Reading and Writing Score:
# Based on the histograms and .describe: For the SAT tests, the histograms are undefined bimodal as well. SAT 2017 Mean Score's median is 559, whereas its mean is 569.11. SAT 2018 Math Mean Score's median is 552.00, and the mean is 563.68. Both the mean and medium dropped compared to the previous year.

# %% [markdown]
# ### Plot and interpret scatter plots
#
# We will be plotting scatter plot for visualization in this section.
#
# For each of the following:
# - SAT vs. ACT math scores for 2017
# - SAT vs. ACT verbal/reading scores for 2017
# - SAT vs. ACT total/composite scores for 2017
# - Total scores for SAT 2017 vs. 2018
# - Composite scores for ACT 2017 vs. 2018
# - SAT Participation & Total Score

# %%
def scatter_plot(dataframe,datax,datay,datax_label,datay_label,plot_title):
    """Building function to plot scatter plot"""
    x = dataframe[datax] ##Getting the data from the dataframe to define x
    y = dataframe[datay] ##Getting the data from the dataframe to define x
    plt.scatter(x,y)  #Plot scatter plot
    w,b = np.polyfit(x,y,deg=1) # Finding the line of best fit, w is the 
    fit_line = w* x + b 
    plt.plot(x,fit_line,'r--') #plotting the line of best fit 
    plt.title(plot_title) #plot title
    plt.xlabel(datax_label) #plot xlabel
    plt.ylabel(datay_label) #plot ylabel
    plt.grid() #plot grid
    plt.show();

# %%
#SAT VS ACT Math Scores for 2017
scatter_plot(combined_df,'sat2017_math','act2017_math','SAT','ACT','2017 MATH SCORE')

# %% [markdown]
# Based on the above scatter plot, there is a weak,negative and linear association between the SAT and ACT 2017 Math score. There are potential outliers.

# %%
#SAT EBRW VS ACT READING Scores for 2017
scatter_plot(combined_df,'sat2017_ebrw','act2017_reading','SAT','ACT','2017 READING/VERBAL SCORE')

# %% [markdown]
# Based on the above scatter plot, there is a weak,negative and linear association between the SAT and ACT 2017 Reading/Verbal score. There are potential outliers.

# %%
#SAT Total Scores VS ACT Composite Scores for 2017
scatter_plot(combined_df,'sat2017_total','act2017_composite','SAT','ACT','2017 TOTAL/COMPOSITE SCORE')

# %% [markdown]
# The above scatter plot shows that there is a weak,negative and linear assocation between SAT and ACT 2017 Total/Composite score. There are potential outliers in the data.

# %%
#Total SAT Scores for 2017 and 2018
scatter_plot(combined_df,'sat2017_total','sat2018_total','2017','2018','SAT TOTAL SCORE')

# %% [markdown]
# The above scatter plot shows that there is a strong,positive,linear assocation between SAT 2017 and 2018 total score. There are a few potential outliers in the data.

# %%
#Total composite scores for 2017 and 2018
scatter_plot(combined_df,'act2017_composite','act2018_composite','2017','2018','ACT COMPOSITE SCORE')

# %% [markdown]
# The above scatter plot shows that there is a strong,positive,linear assocation between ACT 2017 and 2018 composite score. There are a few potential outliers in the data.

# %%
#comparing SAT PARTICIPATION AND TOTAL SCORE
scatter_plot(combined_df,'sat2017_participation','sat2017_total','Participation','Total','2017 SAT PARTICIPATION & TOTAL SCORE')

# %% [markdown]
# During the heatmap plotting, I saw that there is a negative correlation between SAT Participation and its total score. Therefore, I will like to plot a scatter plot to see the relationship between these two mean scores. In the above scatter plot, there is a strong, linear and negative assocation. There seems to have potential outliners. The negative correlation is also being proved by this plot. Therefore, the higher the participation, the lower the mean total score will be.

# %%
scatter_plot(combined_df,'sat2017_participation','act2017_participation','SAT','ACT','2017 PARTICIPATION')

# %% [markdown]
# In the above scatter plot, I am comparing the participation rate between ACT and SAT in 2017. There is a negative, linear and weak association. There seems to have potential outliners. The plot proves that there is a negative correlation. The higher the SAT participants, the lower the ACT participants. So in this case, there is a low amount of participants who are taking two tests in the same year.

# %% [markdown]
# ### Boxplot Analysis
#
# Using boxplot, we will be studying relationship between different features. We will be creating a function to plot them out.

# %%
def box_plotting(dataframe,list_of_columns,title,xlabel,ylabel):
    """function for box plot"""
    fig,ax = plt.subplots(figsize=(8,6))
    sns.boxplot(data = dataframe[list_of_columns],ax=ax,orient='h')
    
    ax.set_title(title) #setting of title
    ax.set_xlabel(xlabel) #setting of xlabel
    ax.set_ylabel(ylabel) #setting of ylabel
    ax.yaxis.grid(True) #enabling the grid

# %%
box_plotting(combined_df,['sat2017_participation','sat2018_participation','act2017_participation','act2018_participation'],'PARTICIPATION','TEST PARTICIPATION PER YEAR','PARTICIPATION RATE' )
#Comparing tests participation rates for 2017 and 2018

# %% [markdown]
# ##### Above is the boxplot for the participation rate for both tests for both years.
#
# ###### Max & Min
# - The maximum is 100 for all tests.
# - The minimum for the SAT 2017 and 2018 tests are both 2 .
# - The minimum for ACT 2017 and 2018 tests are 8 and 7 respectively.
#
# ###### IQR
# - The SAT 2017 IQR is 62.
# - The ACT 2017 IQR is 69.
# - The SAT 2018 IQR is 73.
# - The ACT 2018 IQR is 71.5.
#
# ###### Skewness
# - SAT 2017 is quite close to normal distribution.
# - SAT 2018 is skewed to the left.
# - ACT 2017 is slightly skewed to the left.
# - ACT 2018 has a normal distribution.

# %%
box_plotting(combined_df,['sat2017_ebrw','sat2018_ebrw'],'SAT EVIDENCE-BASED READING AND WRITING','MEAN SCORE PER YEAR','SCORE')
#Comparing SAT ebrw for 2017 and 2018

# %% [markdown]
# ##### Above is the boxplot for SAT Evidence-Based Reading and Writing Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 644 and 482 respectively.
# - The maximum and minimum for 2018 is 643 and 480 respectively.
#
#
# ###### IQR
# - The 2017 IQR is 80.
# - The 2018 IQR is 76.
#
# ###### Skewness
# - Both 2017 and 2018 distributions are skewed to the right.

# %%
box_plotting(combined_df,['sat2017_math','sat2018_math'],'SAT MATH','MEAN SCORE PER YEAR','SCORE')
#Comparing SAT math scores for 2017 and 2018

# %% [markdown]
# ##### Above is the boxplot for the SAT Math Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 651 and 468 respectively.
# - The maximum and minimum for 2018 is 655 and 480 respectively.
#
# ###### IQR
# - The 2017 IQR is 76.
# - The 2018 IQR is 71.
#
# ###### Skewness
# - Both 2017 and 2018 distributions are skewed to the right.

# %%
box_plotting(combined_df,['sat2017_total','sat2018_total'],'SAT TOTAL','MEAN SCORE PER YEAR','SCORE')
#Comparing SAT math scores for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the SAT Total Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 1295 and 950 respectively.
# - The maximum and minimum for 2018 is 1298 and 977 respectively.
#
# ###### IQR
# - The 2017 IQR is 157.
# - The 2018 IQR is 146.5.
#
# ###### Skewness
# - Both 2017 and 2018 distributions are skewed to the right.

# %%
box_plotting(combined_df,['act2017_english','act2018_english'],'ACT ENGLISH','MEAN SCORE PER YEAR','SCORE')
#Comparing ACT English scores for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the ACT English Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 25.5 and 16.3 respectively.
# - The maximum and minimum for 2018 is 26 and 16.6 respectively.
#
# ###### IQR
# - The 2017 IQR is 4.3.
# - The 2018 IQR is 4.6.
#
# ###### Skewness
# - 2017 distribution seems slightly skewed to the right.
# - 2018 distribution is skewed to the right.

# %%
box_plotting(combined_df,['act2017_reading','act2018_reading'],'ACT READING','MEAN SCORE PER YEAR','SCORE')
#Comparing ACT Reading scores for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the ACT Reading Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 26 and 18.1 respectively.
# - The maximum and minimum for 2018 is 26.1 and 18 respectively.
#
# ###### IQR
# - The 2017 IQR is 3.7.
# - The 2018 IQR is 3.65.
#
# ###### Skewness
# - 2017 distribution seems slightly skewed to the right.
# - 2018 distribution is skewed to the right

# %%
box_plotting(combined_df,['act2017_math','act2018_math'],'ACT MATH','MEAN SCORE PER YEAR','SCORE')
#comparing ACT Math score for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the ACT Math Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 25.3 and 18 respectively.
# - The maximum and minimum for 2018 is 25.2 and 17 respectively.
#
# ###### IQR
# - The 2017 IQR is 3.7.
# - The 2018 IQR is 3.75.
#
# ###### Skewness
# - 2017 distribution seems slightly skewed to the right.
# - 2018 distribution is skewed to the right

# %%
box_plotting(combined_df,['act2017_science','act2018_science'],'ACT SCIENCE','MEAN SCORE PER YEAR','SCORE')
#comparing ACT Science score for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the ACT Science Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 24.9 and 18.2 respectively.
# - The maximum and minimum for 2018 is 24.9 and 17.9 respectively.
#
# ###### IQR
# - The 2017 IQR is 3.25.
# - The 2018 IQR is 3.2.
#
# ###### Skewness
# - 2017 distribution seems slightly skewed to the right.
# - 2018 distribution is skewed to the right

# %%
box_plotting(combined_df,['act2017_composite','act2018_composite'],'ACT COMPOSITE','MEAN SCORE PER YEAR','SCORE')
#comparing ACT Composite score for 2017 and 2018

# %% [markdown]
# ##### Above are the boxplots for the ACT Composite Mean Score for 2017 and 2018.
#
# ###### Max & Min
# - The maximum and minimum for 2017 is 25.5 and 17.8 respectively.
# - The maximum and minimum for 2018 is 25.6 and 17.7 respectively.
#
# ###### IQR
# - The 2017 IQR is 3.8.
# - The 2018 IQR is 3.55.
#
# ###### Skewness
# - Both distribution are skewed to the right.

# %% [markdown]
# ## Descriptive and Inferential Statistics

# %% [markdown]
# ### Summarizing Distributions
#
# Above, we used pandas `describe` to provide quick summary statistics of our numeric columns. We also demonstrated many visual relationships.
#
# As data scientists, having a complete understanding of data is imperative prior to modeling.
#
# While we will continue to build our analytic tools, we know that measures of *central tendency*, *spread*, and *shape/skewness* provide a quick summary of distributions.
#
# For each variable in your data, summarize the underlying distributions (in words & statistics)
#  - Be thorough in your verbal description of these distributions.
#  - Be sure to back up these summaries with statistics.

# %%
combined_df.describe().transpose()
# Out:
#                        count         mean        std    min      25%     50%  \
# act2017_participation   51.0    65.254902  32.140842    8.0    31.00    69.0
# act2017_english         51.0    20.931373   2.353677   16.3    19.00    20.7
# act2017_math            51.0    21.182353   1.981989   18.0    19.40    20.9
# act2017_reading         51.0    22.013725   2.067271   18.1    20.45    21.8
# act2017_science         51.0    21.450980   1.739353   18.2    19.95    21.3
# act2017_composite       51.0    21.519608   2.020695   17.8    19.80    21.4
# sat2017_participation   51.0    39.803922  35.276632    2.0     4.00    38.0
# sat2017_ebrw            51.0   569.117647  45.666901  482.0   533.50   559.0
# sat2017_math            51.0   556.882353  47.121395  468.0   523.50   548.0
# sat2017_total           51.0  1126.098039  92.494812  950.0  1055.50  1107.0
# act2018_participation   51.0    61.647059  34.080976    7.0    28.50    66.0
# ...

# %% [markdown]
# Using .describe for the dataframe, we are able to summarize the central tendency, spread and skewness of a dataset's distribution. Central tendency is determined by mean and median. Spread is determined by the standard deviaton and interquartile range(IQR),which is the difference of 75% and 25%. Using mean and median, we are able to tell the skewness of the distribution. In every distribution, it has a count of 51.
#
# For ACT participation in 2017 and 2018, there is a decrease of 3.6 and 3 in the mean and median respectively. Its IQR decreases from 69 to 66, but the standard deviation increased from 32.14 to 34.08. The data is more dispersed in 2018. In both years, the median is larger than its mean, so the distribution is skewed to the right. Both years' composite and sub-tests mean scores are quite near to each other, ranging from 20.93 to 22.01.
#
# For SAT participation in 2017 and 2018, there is an increase of 5.9 and 14 in the mean and median respectively. Its IQR increases from 62 to 73. There is an increase of 2.04 in its standard deviation, indicating that the data is more dispersed in 2018. As the median is larger than the mean in both years,the distribution is skewed to the right. Its total score for both years is quite close to each other, 1126 for 2017 and 1120 for 2018. It seemed that as there is a negative correlation between participation and total score.
#
# Comparing ACT and SAT participation rates in 2017 and 2018, there is a negative correlation. When the ACT participation decreased between 2017 to 2018, there is an increase in the SAT participation. The increase amount in SAT is higher than the decrease amount in ACT.

# %% [markdown]
# ### Distributions in the data
#
# In this dataset, each data represents a sample from a population.
# For example, for ACT math test:
# - Population: the test results of all the students who take this test, nation-wide.
# - Population mean: is the national average of ACT math test (total scores/total no. of test takers)
# - Sample: the state means of ACT math test. We have 51 samples (51 states)
#
# ***According to CLT, we generally assuming that data we sample from a population will be normally distributed. Do we observe this trend?***

# %%
def sample_mean(data,column,size,frequency):
    """function for getting sample_mean"""
    populationlist = data[column].values.tolist() ##Getting the population and putting into a list
    population_mean = (sum(populationlist)/len(populationlist)) ###Getting population mean
    sample_mean = [np.mean(np.random.choice(a = int(population_mean), size = [size])) for i in range(frequency)] ##Getting sample mean based on the range
    return sample_mean

# %%
def dist_plot(sample,title):
    """function for plotting"""
    sns.distplot(sample,bins=30,kde=True).set_title(title)

# %% [markdown]
# Answer: Yes, after generating the sample mean for a certain amount of time, a normal distribution will be plotted.

# %% [markdown]
# Does This Assumption Hold for:
#     - Math
#     - Reading
#     - Rates
# Explain your answers for each distribution and how you think this will affect estimates made from these data.

# %%
act17math_sample_mean = sample_mean(combined_df,'act2017_math',51,5000) #Sample mean for ACT2017 Math

# %%
dist_plot(act17math_sample_mean,"ACT 2017 Math Results") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
act18math_sample_mean = sample_mean(combined_df,'act2018_math',51,5000) #Sample mean for ACT2018 Math

# %%
dist_plot(act17math_sample_mean,"ACT 2018 Math Results") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat17math_sample_mean = sample_mean(combined_df,'sat2017_math',51,5000) #Sample mean for SAT2017 Math

# %%
dist_plot(sat17math_sample_mean,"SAT 2017 Math Results") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat18math_sample_mean = sample_mean(combined_df,'sat2018_math',51,5000) #Sample mean for SAT2018 Math

# %%
dist_plot(sat18math_sample_mean,"SAT 2018 Math Results") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### The Math Results
#
# After generating the sample mean for each test 5000 times, the distributions return to be normal. As this is selecting random samples from a population and clustering them together, it will help us to make a very good estimate of the population mean.

# %%
act17reading_sample_mean = sample_mean(combined_df,'act2017_reading',51,5000) #Reading result for ACT 2017

# %%
dist_plot(act17reading_sample_mean,"ACT 2017 Reading Results") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
act18reading_sample_mean = sample_mean(combined_df,'act2018_reading',51,5000)#Reading result for ACT 2018

# %%
dist_plot(act18reading_sample_mean,"ACT 2018 Reading Results")#Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat17ebrw_sample_mean = sample_mean(combined_df,'sat2017_ebrw',51,5000) #EBRW result for SAT 2017

# %%
dist_plot(sat17ebrw_sample_mean,"SAT 2017 EBRW Results")#Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat18ebrw_sample_mean = sample_mean(combined_df,'sat2018_ebrw',51,5000) #EBRW result for SAT 2018

# %%
dist_plot(sat17ebrw_sample_mean,"SAT 2018 EBRW Results")#Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### Reading and Evidence-Based Reading and Writing Result
#
# After generating the above sample means for 5000 times each, the distribution returns to be normal. With the amount of sample means generating and the normal distribution, we will be able to tell the mean, median and standard deviation easier.

# %%
act17participation_sample_mean = sample_mean(combined_df,'act2017_participation',51,5000)#Participation Rate for ACT 2017

# %%
dist_plot(act17participation_sample_mean,"ACT 2017 Participation Rate") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
act18participation_sample_mean = sample_mean(combined_df,'act2018_participation',51,5000)#Participation Rate for ACT 2018

# %%
dist_plot(act18participation_sample_mean,"ACT 2018 Participation Rate") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat17participation_sample_mean = sample_mean(combined_df,'sat2017_participation',51,5000)#Participation Rate for SAT 2017

# %%
dist_plot(act17participation_sample_mean,"SAT 2017 Participation Rate") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sat18participation_sample_mean = sample_mean(combined_df,'sat2018_participation',51,5000)#Participation Rate for SAT 2018

# %%
dist_plot(sat18participation_sample_mean,"SAT 2018 Participation Rate") #Plotting the distribution
# Out:
# C:\Users\User\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ###### SAT & ACT Participation Rate
#
# After generating the tests Participation Rate for 5000 times each, the distribution returns to be normal. Similar to the previous two variable examples, as the sample size increases, the sampling error will decrease. The mean and standard deviation will be easily to be predicted.

# %% [markdown]
# ### Estimate Limits of Data
#
# Suppose we only seek to understand the relationship between SAT and ACT participation rates in 2017.
#
# ##### Does it make sense to conduct statistical inference given these data specifically?
#
# Why or why not?
#
# *(think about granularity, aggregation, the relationships between populations size & rates...consider the actually populations these data describe in answering this question)*

# %% [markdown]
# Yes. Both variables are actually from the population which are students deciding whether to take SAT and ACT. The range for both variables is also from 0 to 100. There is also a negative correlation as when an individual takes SAT, he/she have a low chance of taking ACT in the same year. The units used for measuring both variables are the same.

# %% [markdown]
# ##### Is it appropriate to compare *these* specific SAT and ACT math scores  - can we say students with higher SAT math score is better than those with lower ACT math score, or vice versa?
#
# Why or why not?

# %% [markdown]
# It may not be appropriate to compare the two tests math scores. Despite having a negative correlation between both tests, the standards of the tests are different. Their score range is also different. SAT scores are marked between 200-800, whereas ACT scores are marked between 1 and 36. However, one factor which causes the negative correlation could be that, when an individual takes a SAT math test, he/she may not be taking an ACT math test in the same year.

# %% [markdown]
# ## Outside Research

# %% [markdown]
# In this section, we will be studying on three random states which are offering both ACT and SAT. We will be comparing them to additional research from outside sources. The three random states are Nevada, DC and Minnesota.

# %%
Nevada = combined_df.loc[combined_df['state']=='Nevada',['state','act2017_participation','act2018_participation','sat2017_participation','sat2018_participation']]
DC = combined_df.loc[combined_df['state']=='District of Columbia',['state','act2017_participation','act2018_participation','sat2017_participation','sat2018_participation']]
Minnesota = combined_df.loc[combined_df['state']=='Minnesota',['state','act2017_participation','act2018_participation','sat2017_participation','sat2018_participation']]

# %%
Nevada #Comparing data on Nevada
# Out:
#      state  act2017_participation  act2018_participation  \
# 28  Nevada                  100.0                  100.0
#
#     sat2017_participation  sat2018_participation
# 28                   26.0                   23.0

# %% [markdown]
# Based on information from College Raptor, junior students can take ACT for free, that may be one of the factors which causes the full ACT participation in the state. In University of Nevada, Reno, they accept either ACT or SAT scores for entry. That might explain why there is a certain amount of SAT participation.
#
# Source from the University of Nevada, Reno: https://www.unr.edu/admissions/undergraduate/freshman/requirements#:~:text=Standardized%20test%20scores%20are%20not%20required%20for%20admission%20to%20the,placement%20in%20first%20year%20courses.

# %%
DC #Comparing data on DC
# Out:
#                   state  act2017_participation  act2018_participation  \
# 8  District of Columbia                   32.0                   32.0
#
#    sat2017_participation  sat2018_participation
# 8                  100.0                   92.0

# %% [markdown]
# Based on information from College Raptor, SAT is offered free to all juniors and seniors. That might explain why the participation in SAT is higher than in ACT. In University of the District of Columbia, they require students to have either SAT or ACT to enter. That might explains why there is also a certain amount of ACT participation.
#
# Source from University of the District of Columbia:
# https://www.udc.edu/admissions/information-for-college-advisors/#:~:text=Admissions%20Process,-There%20are%20slight&text=In%20general%2C%20UDC%20requires%20students%20to%3A&text=Submit%20official%20SAT%20or%20ACT,other%20colleges%20or%20universities%20attended.

# %%
Minnesota #Comparing data on Minnesota
# Out:
#         state  act2017_participation  act2018_participation  \
# 23  Minnesota                  100.0                   99.0
#
#     sat2017_participation  sat2018_participation
# 23                    3.0                    4.0

# %% [markdown]
# In Minnesota, a few schools or districts can administer the SAT exam to their students for free, but it is optional. ACT is not free in Minnesota. Schools in Minnesota viewed SAT and ACT as equal for admissions. In the upcoming admission, fall 2021, ACT or SAT are not required for admission. The policy change was made to ensure every student has the opportunity to submit a complete application.
#
# Source from University of Minnesota: https://admissions.tc.umn.edu/freshman/test_requirements.html

# %% [markdown]
# Beside the subsidies in different states for the tests, majority of the states viewed SAT and ACT as equal.
#
# College Raptor Source from https://www.collegeraptor.com/getting-in/articles/act-sat/states-act-sat-given-free/

# %% [markdown]
# ## Conclusions and Recommendations

# %%
combined_df[['state','act2018_participation','sat2018_participation','act2018_composite','sat2018_total']].describe()
# Out:
#        act2018_participation  sat2018_participation  act2018_composite  \
# count              51.000000              51.000000          51.000000
# mean               61.647059              45.745098          21.486275
# std                34.080976              37.314256           2.106278
# min                 7.000000               2.000000          17.700000
# 25%                28.500000               4.500000          19.950000
# 50%                66.000000              52.000000          21.300000
# 75%               100.000000              77.500000          23.550000
# max               100.000000             100.000000          25.600000
#
#        sat2018_total
# count      51.000000
# mean     1120.019608
# std        94.155083
# min       977.000000
# 25%      1057.500000
# 50%      1098.000000
# 75%      1204.000000
# max      1298.000000

# %%
combined_df.loc[combined_df['state']=='Iowa',['state','act2017_participation','sat2017_participation','act2018_participation','sat2018_participation']] #Comparing data on Iowa
# Out:
#    state  act2017_participation  sat2017_participation  act2018_participation  \
# 15  Iowa                   67.0                    2.0                   68.0
#
#     sat2018_participation
# 15                    3.0

# %%
combined_df.loc[combined_df['state']=='Iowa',['state','act2017_composite','sat2017_total','act2018_composite','sat2018_total']] #Comparing data on Iowa
# Out:
#    state  act2017_composite  sat2017_total  act2018_composite  sat2018_total
# 15  Iowa               21.9         1275.0               21.8         1265.0

# %% [markdown]
# After the analysis and visualization of data, some trends were found.
#
# 1) There seemed to have a negative correlation of ACT participation rate and SAT participation rate. It seemed that if a candidate were to take SAT, he/she will not take ACT in the same year, vice versa.
#
# 2) Participation rates for both tests have a negative correlation with their respective composite/total scores. When the participation rate increases, the scores will decrease.
#
# 3) Positive correlations were found in both tests' composite/total scores with their sub-tests scores.
#
#
# Therefore, I recommend to concentrate on states that do not have a high ACT participation but a very low SAT participation.
#
# An example will be Iowa. The table above shows both tests participation in both year. The ACT 2018 participation rates increased by 1 from 2017. The SAT 2018 partcipation rates increases by 1 as well. The ACT 2018 composite score decreased by 0.1 as compared to 2017. The SAT 2018 total score decreased by 10 as compared to 2017. These two decreases in both tests composite and total score proved the negative correlation with the participation rate of the tests.
#
# From outside research, it is not free to take either test in the state. To enter the university of Iowa, the applicant will require a ACT composite score of 26 or SAT total of 1230.
#
# A recommendation will be to work with the Iowa's education board for subsidized SAT tests. As Iowa's median household income is lower than the national's median household, it might be able to help some students. The schools can also implement SAT to be taken on school days, students might treat it as part of the curriculum.
#
# It might help in encouraging more students to enter college after high school. Based on sources from United States Census Bureau, the education attainment for high school or higher in Iowa is 92.6%, however 31% is only from high school. Therefore, more SAT participation will encourage them to enter college as SAT is one of the requirements.
#
# Source from University of Iowa: https://admissions.uiowa.edu/academics/first-year-admission
#
# Iowa's median household income. Source from United States Census Bureau: https://www.census.gov/quickfacts/fact/table/US,IA/INC110218
#
# Iowa's educational attainment. Source from United States Census Bureau:
# https://data.census.gov/cedsci/profile?g=0400000US19
